# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatviswa/SP25_DS6050/blob/main/Copy_of_Download_flowchart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install kagglehub

# %%
import PIL
import pickleshare
import kagglehub
# Download latest version
path = kagglehub.dataset_download("yaswanthkrishna2002/flowcharts-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 74.8M/74.8M [00:02<00:00, 37.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/yaswanthkrishna2002/flowcharts-dataset/versions/3

# %%
from pathlib import Path
import json
data_dir = Path("/root/.cache/kagglehub/datasets/yaswanthkrishna2002/flowcharts-dataset/versions/3/Flow chart detection.v2i.darknet/train")

# %%
data_dir
# Out:
# PosixPath('/root/.cache/kagglehub/datasets/yaswanthkrishna2002/flowcharts-dataset/versions/3/Flow chart detection.v2i.darknet/train')

# %%
flowcharts = list(data_dir.glob('*.jpg'))

# %%
PIL.Image.open(str(flowcharts[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>
